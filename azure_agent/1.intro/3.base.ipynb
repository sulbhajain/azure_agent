# %%
# 📚 Exploring Agentic Frameworks - Basic Agent Example
# This example demonstrates core concepts of the Microsoft Agent Framework

# 📦 Import Required Libraries
import os                     # For environment variable access
from random import randint    # For generating random selections
from dotenv import load_dotenv  # For loading .env configuration files

# %%
# 🤖 Import Core Agent Framework Components
# ChatAgent: The main conversational agent class
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Initialize Environment Configuration
# Load environment variables from .env file
# This enables secure storage of API keys and endpoints
load_dotenv()
# Out:
# True

# %%
# 🛠️ Tool Function: Random Destination Generator
# This demonstrates how to create tools that agents can use
# Tools extend the agent's capabilities beyond just conversation
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    This function serves as a tool that the agent can call when it needs
    to suggest a random destination for travel planning.
    
    Returns:
        str: A randomly selected destination from the predefined list
    """
    # Curated list of popular vacation destinations worldwide
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a randomly selected destination
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client
# This demonstrates how to connect to GitHub Models (OpenAI-compatible API)
# The client handles all communication with the AI model
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # API endpoint URL
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model identifier (e.g., gpt-4o-mini)
)

# %%
AGENT_NAME ="TravelAgent"

AGENT_INSTRUCTIONS = """You are a helpful AI Agent that can help plan vacations for customers.

Important: When users specify a destination, always plan for that location. Only suggest random destinations when the user hasn't specified a preference.

When the conversation begins, introduce yourself with this message:
"Hello! I'm your TravelAgent assistant. I can help plan vacations and suggest interesting destinations for you. Here are some things you can ask me:
1. Plan a day trip to a specific location
2. Suggest a random vacation destination
3. Find destinations with specific features (beaches, mountains, historical sites, etc.)
4. Plan an alternative trip if you don't like my first suggestion

What kind of trip would you like me to help you plan today?"

Always prioritize user preferences. If they mention a specific destination like "Bali" or "Paris," focus your planning on that location rather than suggesting alternatives.
"""

# %%
# 🤖 Create the Basic Agent
# This demonstrates the core agent creation pattern in the framework
# Key components: chat client, instructions, and tools
agent = ChatAgent(
    name = AGENT_NAME,  # The name of the agent
    chat_client=openai_chat_client,  # The AI model client for generating responses
    instructions=AGENT_INSTRUCTIONS,  # Instructions for the agent's behavior
    tools=[get_random_destination]   # List of available tools the agent can use
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# Hello! I'm your TravelAgent assistant. I can help plan vacations and suggest interesting destinations for you.
#
# Since you mentioned a day trip but didn't specify a location, could you please let me know where you'd like to go? If you don't have a specific destination in mind, I can suggest a random one!

# %%
response2 = await agent.run("I don't like that destination. Plan me another vacation.",thread= thread)

# %%
last_message = response2.messages[-1]
text_content = last_message.contents[0].text
print("Change plan:")
print(text_content)
# Out:
# Change plan:
# How about a day trip to Sydney, Australia? Here’s a plan for a fantastic day in this vibrant city:
#
# ### Morning:
# 1. **Breakfast at The Rocks**: Start your day with a delicious breakfast at one of the cafes in The Rocks area, where you can enjoy views of the Sydney Harbour Bridge.
# 2. **Sydney Opera House**: After breakfast, take a guided tour of the iconic Sydney Opera House to learn about its history and architecture.
#
# ### Midday:
# 3. **Royal Botanic Garden**: Stroll through the stunning Royal Botanic Garden, soaking in the lush greenery and beautiful views of the Sydney Harbour.
# 4. **Lunch at Circular Quay**: Grab lunch at one of the eateries in Circular Quay and watch the ferries come and go.
#
# ### Afternoon:
# 5. **Ferry to Manly Beach**: Take a scenic ferry ride to Manly Beach. Enjoy the beautiful coastal views and relax on the beach or take a walk along the promenade.
# 6. **Explore Manly**: Visit local shops or grab a coffee at one of the beachside cafes.
#
# ### Evening:
# 7. **Return to Sydney**: Take the ferry back to Circular Quay as the sun sets, providing stunning views of the city skyline.
# 8. **Dinner at Darling Harbour**: Enjoy dinner at Darling Harbour, where you can find a variety of restaurants with a beautiful waterfront view.
#
# ### Optional Night Activity:
# - **Sydney Tower Eye**: If you have time, visit the Sydney Tower Eye for breathtaking panoramic views of the city at night.
#
# Would you like to make any adjustments, or is there anything specific you'd like to include in your day trip?
