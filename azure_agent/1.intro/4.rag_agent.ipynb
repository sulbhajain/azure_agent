# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.3.6-cp39-abi3-macosx_10_12_x86_64.whl.metadata (7.2 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pydantic>=1.9 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from chromadb) (2.11.10)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.3-cp310-cp310-macosx_10_9_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from chromadb) (2.2.6)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from chromadb) (4.15.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.23.2-cp310-cp310-macosx_13_0_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from chromadb) (1.39.0)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Downloading tokenizers-0.22.1-cp39-abi3-macosx_10_12_x86_64.whl.metadata (6.8 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from chromadb) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from chromadb) (1.76.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from chromadb) (0.20.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-34.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from chromadb) (6.0.3)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (14 kB)
# Collecting orjson>=3.9.12 (from chromadb)
#   Downloading orjson-3.11.5-cp310-cp310-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (41 kB)
# Requirement already satisfied: httpx>=0.27.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: requests<3.0,>=2.7 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in /Users/sulbhajain/.local/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/sulbhajain/.local/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.8.2)
# Requirement already satisfied: backoff>=1.10.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.11.12)
# Requirement already satisfied: packaging>=19.1 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (25.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting tomli>=1.1.0 (from build>=1.0.3->chromadb)
#   Using cached tomli-2.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.43.0)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Downloading websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: protobuf in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-proto==1.39.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers>=0.13.2->chromadb)
#   Downloading huggingface_hub-1.2.2-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Downloading filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Downloading fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Using cached hf_xet-1.2.0-cp37-abi3-macosx_10_12_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: shellingham in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.4)
# Collecting typer-slim (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Downloading typer_slim-0.20.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: click>=8.0.0 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: httptools>=0.6.3 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.14.1->chromadb)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading chromadb-1.3.6-cp39-abi3-macosx_10_12_x86_64.whl (20.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 45.5 MB/s  0:00:00m0:00:010:01
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
# Downloading bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl (495 kB)
# Downloading build-1.3.0-py3-none-any.whl (23 kB)
# Downloading kubernetes-34.1.0-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 39.6 MB/s  0:00:00
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.0-cp310-cp310-macosx_10_9_x86_64.whl (40 kB)
# Downloading onnxruntime-1.23.2-cp310-cp310-macosx_13_0_x86_64.whl (19.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 60.6 MB/s  0:00:00 eta 0:00:01
# Downloading orjson-3.11.5-cp310-cp310-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (245 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pybase64-1.4.3-cp310-cp310-macosx_10_9_x86_64.whl (38 kB)
# Downloading tokenizers-0.22.1-cp39-abi3-macosx_10_12_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 50.2 MB/s  0:00:00
# Downloading huggingface_hub-1.2.2-py3-none-any.whl (520 kB)
# Using cached hf_xet-1.2.0-cp37-abi3-macosx_10_12_x86_64.whl (2.9 MB)
# Downloading fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Using cached tomli-2.3.0-py3-none-any.whl (14 kB)
# Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 57.2 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 9.8 MB/s  0:00:00
# Downloading typer_slim-0.20.0-py3-none-any.whl (47 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53803 sha256=e8d076806c1b1e6b47709b040b5c99ddfbb25aa29324d1840c939c40e23e7a0e
#   Stored in directory: /Users/sulbhajain/Library/Caches/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, mpmath, flatbuffers, durationpy, websocket-client, urllib3, typer-slim, tomli, sympy, pyproject_hooks, pybase64, overrides, orjson, oauthlib, mmh3, importlib-resources, humanfriendly, hf-xet, fsspec, filelock, bcrypt, coloredlogs, build, requests-oauthlib, posthog, onnxruntime, kubernetes, huggingface-hub, tokenizers, chromadb
#   Attempting uninstall: urllib3m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/30 [websocket-client]
#     Found existing installation: urllib3 2.6.1━━━━━━━━━━━━━━━━  4/30 [websocket-client]
#     Uninstalling urllib3-2.6.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/30 [websocket-client]
#       Successfully uninstalled urllib3-2.6.1━━━━━━━━━━━━━━━━━━  4/30 [websocket-client]
#   Attempting uninstall: posthog━━━━━━━╸━━━━━━━━━ 23/30 [requests-oauthlib]s]
#     Found existing installation: posthog 7.0.10m━━━━━━━━━ 23/30 [requests-oauthlib]
#     Uninstalling posthog-7.0.1:━━━╸━━━━━━━━━ 23/30 [requests-oauthlib]
#       Successfully uninstalled posthog-7.0.1╺━━━━━━━ 24/30 [posthog]thlib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30/30 [chromadb]/30 [chromadb]s]-hub]
# Successfully installed bcrypt-5.0.0 build-1.3.0 chromadb-1.3.6 coloredlogs-15.0.1 durationpy-0.10 filelock-3.20.0 flatbuffers-25.9.23 fsspec-2025.12.0 hf-xet-1.2.0 huggingface-hub-1.2.2 humanfriendly-10.0 importlib-resources-6.5.2 kubernetes-34.1.0 mmh3-5.2.0 mpmath-1.3.0 oauthlib-3.3.1 onnxruntime-1.23.2 orjson-3.11.5 overrides-7.7.0 posthog-5.4.0 pybase64-1.4.3 pypika-0.48.9 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 sympy-1.14.0 tokenizers-0.22.1 tomli-2.3.0 typer-slim-0.20.0 urllib3-2.3.0 websocket-client-1.9.0

# %%
import os
import time
import asyncio
from typing import List, Dict
from dotenv import load_dotenv

from autogen_agentchat.agents import AssistantAgent
from autogen_core import CancellationToken
from autogen_agentchat.messages import TextMessage
from azure.core.credentials import AzureKeyCredential
from autogen_ext.models.azure import AzureAIChatCompletionClient

import chromadb

load_dotenv()
# Out:
# True

# %%
client = AzureAIChatCompletionClient(
    model="gpt-4o-mini",
    endpoint="https://models.inference.ai.azure.com",
    credential=AzureKeyCredential(os.getenv("GITHUB_TOKEN")),
    model_info={
        "json_output": True,
        "function_calling": True,
        "vision": True,
        "family": "unknown",
    },
)
# Out:
# /Users/sulbhajain/opt/anaconda3/envs/azure_agent_py310/lib/python3.10/site-packages/autogen_ext/models/azure/_azure_ai_client.py:307: UserWarning: Missing required field 'structured_output' in ModelInfo. This field will be required in a future version of AutoGen.
#   validate_model_info(config["model_info"])

# %% [markdown]
# ### Vector-store initialization

# %%
# Initialize ChromaDB with persistent storage
chroma_client = chromadb.PersistentClient(path="./chroma_db")
collection = chroma_client.create_collection(
    name="travel_documents",
    metadata={"description": "travel_service"},
    get_or_create=True
)

# Enhanced sample documents
documents = [
    "Contoso Travel offers luxury vacation packages to exotic destinations worldwide.",
    "Our premium travel services include personalized itinerary planning and 24/7 concierge support.",
    "Contoso's travel insurance covers medical emergencies, trip cancellations, and lost baggage.",
    "Popular destinations include the Maldives, Swiss Alps, and African safaris.",
    "Contoso Travel provides exclusive access to boutique hotels and private guided tours."
]

# Add documents with metadata
collection.add(
    documents=documents,
    ids=[f"doc_{i}" for i in range(len(documents))],
    metadatas=[{"source": "training", "type": "explanation"} for _ in documents]
)
# Out:
# /Users/sulbhajain/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:02<00:00, 29.4MiB/s]

# %%
class ContextProvider:
    def __init__(self, collection):
        self.collection = collection
        # Simulated weather database
        self.weather_database = {
            "new york": {"temperature": 72, "condition": "Partly Cloudy", "humidity": 65, "wind": "10 mph"},
            "london": {"temperature": 60, "condition": "Rainy", "humidity": 80, "wind": "15 mph"},
            "tokyo": {"temperature": 75, "condition": "Sunny", "humidity": 50, "wind": "5 mph"},
            "sydney": {"temperature": 80, "condition": "Clear", "humidity": 45, "wind": "12 mph"},
            "paris": {"temperature": 68, "condition": "Cloudy", "humidity": 70, "wind": "8 mph"},
        }
    
    def get_retrieval_context(self, query: str) -> str:
        """Retrieves relevant documents from vector database based on query."""
        results = self.collection.query(
            query_texts=[query],
            include=["documents", "metadatas"],
            n_results=2,
            
        )
        context_strings = []
        if results and results.get("documents") and len(results["documents"][0]) > 0:
            for doc, meta in zip(results["documents"][0], results["metadatas"][0]):
                context_strings.append(f"Document: {doc}\nMetadata: {meta}")
        return "\n\n".join(context_strings) if context_strings else "No relevant documents found"
    
    def get_weather_data(self, location: str) -> str:
        """Simulates retrieving weather data for a given location."""
        if not location:
            return ""
            
        location_key = location.lower()
        if location_key in self.weather_database:
            data = self.weather_database[location_key]
            return f"Weather for {location.title()}:\n" \
                   f"Temperature: {data['temperature']}°F\n" \
                   f"Condition: {data['condition']}\n" \
                   f"Humidity: {data['humidity']}%\n" \
                   f"Wind: {data['wind']}"
        else:
            return f"No weather data available for {location}."
    
    def get_unified_context(self, query: str, location: str = None) -> str:
        """Returns a unified context combining both document retrieval and weather data."""
        retrieval_context = self.get_retrieval_context(query)
        
        weather_context = ""
        if location:
            weather_context = self.get_weather_data(location)
            weather_intro = f"\nWeather Information for {location}:\n"
        else:
            weather_intro = ""
        
        return f"Retrieved Context:\n{retrieval_context}\n\n{weather_intro}{weather_context}"

# %%
# Create agents with enhanced capabilities
assistant = AssistantAgent(
    name="assistant",
    model_client=client,
    system_message=(
        "You are a helpful AI assistant that provides answers using ONLY the provided context. "
        "Do NOT include any external information. Base your answer entirely on the context given below."
    ),
)

# %%
async def ask_rag_agent(query: str, context_provider: ContextProvider, location: str = None):
    """
    Sends a query to the assistant agent with context from the provider.
    
    Args:
        query: The user's question
        context_provider: The context provider instance
        location: Optional location for weather queries
    """
    try:
        # Get unified context
        context = context_provider.get_unified_context(query, location)
        
        # Augment the query with context
        augmented_query = (
            f"{context}\n\n"
            f"User Query: {query}\n\n"
            "Based ONLY on the above context, please provide a helpful answer."
        )

        # Send the augmented query to the assistant
        start_time = time.time()
        response = await assistant.on_messages(
            [TextMessage(content=augmented_query, source="user")],
            cancellation_token=CancellationToken(),
        )
        processing_time = time.time() - start_time
        
        return {
            'query': query,
            'response': response.chat_message.content,
            'processing_time': processing_time,
            'location': location
        }
    except Exception as e:
        print(f"Error processing query: {e}")
        return None

# %%
async def main():
    # Initialize context provider
    context_provider = ContextProvider(collection)
    
    # Example queries
    queries = [
        {"query": "What does Contoso's travel insurance cover?"},
        {"query": "What's the weather like in London?", "location": "london"},
        {"query": "What luxury destinations does Contoso offer and what's the weather in Paris?", "location": "paris"},
    ]
    
    print("=== Autogen RAG Demo ===")
    for query_data in queries:
        query = query_data["query"]
        location = query_data.get("location")
        
        print(f"\n\nQuery: {query}")
        if location:
            print(f"Location: {location}")
        
        # Show the context being used
        context = context_provider.get_unified_context(query, location)
        print("\n--- Context Used ---")
        print(context)
        print("-------------------")
        
        # Get response from the agent
        result = await ask_rag_agent(query, context_provider, location)
        if result:
            print(f"\nResponse: {result['response']}")
        print("\n" + "="*50)

# %%
if __name__ == "__main__":
    if asyncio.get_event_loop().is_running():
        await main()
    else:
        asyncio.run(main())
# Out:
# === Autogen RAG Demo ===
#
#
# Query: What does Contoso's travel insurance cover?
#
# --- Context Used ---
# Retrieved Context:
# Document: Contoso's travel insurance covers medical emergencies, trip cancellations, and lost baggage.
# Metadata: {'type': 'explanation', 'source': 'training'}
#
# Document: Contoso Travel offers luxury vacation packages to exotic destinations worldwide.
# Metadata: {'source': 'training', 'type': 'explanation'}
#
#
# -------------------
#
# Response: Contoso's travel insurance covers medical emergencies, trip cancellations, and lost baggage.
#
# ==================================================
#
#
# Query: What's the weather like in London?
# Location: london
#
# --- Context Used ---
# Retrieved Context:
# Document: Popular destinations include the Maldives, Swiss Alps, and African safaris.
# Metadata: {'source': 'training', 'type': 'explanation'}
#
# Document: Contoso Travel offers luxury vacation packages to exotic destinations worldwide.
# Metadata: {'type': 'explanation', 'source': 'training'}
#
#
# Weather Information for london:
# Weather for London:
# Temperature: 60°F
# Condition: Rainy
# Humidity: 80%
# Wind: 15 mph
# -------------------
#
# Response: The weather in London is 60°F, rainy, with a humidity of 80% and wind at 15 mph.
#
# ==================================================
#
#
# Query: What luxury destinations does Contoso offer and what's the weather in Paris?
# Location: paris
#
# --- Context Used ---
# Retrieved Context:
# Document: Contoso Travel offers luxury vacation packages to exotic destinations worldwide.
# Metadata: {'type': 'explanation', 'source': 'training'}
#
# Document: Contoso Travel provides exclusive access to boutique hotels and private guided tours.
# Metadata: {'source': 'training', 'type': 'explanation'}
#
#
# Weather Information for paris:
# Weather for Paris:
# Temperature: 68°F
# Condition: Cloudy
# Humidity: 70%
# Wind: 8 mph
# -------------------
#
# Response: Contoso Travel offers luxury vacation packages to exotic destinations worldwide and provides exclusive access to boutique hotels and private guided tours. The weather in Paris is 68°F, cloudy, with a humidity of 70% and wind at 8 mph.
#
# ==================================================
