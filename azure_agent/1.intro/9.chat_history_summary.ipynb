# %% [markdown]
# Ref: https://github.com/microsoft/ai-agents-for-beginners/blob/main/12-context-engineering/code_samples/12-chat_summarization.ipynb

# %%
# Import necessary packages
import json
import os
import asyncio
from datetime import datetime
from pathlib import Path

from dotenv import load_dotenv
from IPython.display import display, HTML, Markdown
from typing import Annotated, Optional

from openai import AsyncOpenAI

from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion

from semantic_kernel.agents import ChatCompletionAgent, ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
from semantic_kernel.connectors.ai.completion_usage import CompletionUsage
from semantic_kernel.contents import ChatHistorySummarizationReducer
from semantic_kernel.functions import kernel_function

# %%
# Load environment variables
load_dotenv()

# Create Azure OpenAI service
# chat_service = AzureChatCompletion(
#     deployment_name=os.getenv("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME"),
#     endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
#     api_key=os.getenv("AZURE_OPENAI_API_KEY"),
# )
client = AsyncOpenAI(
    api_key=os.getenv("GITHUB_TOKEN"), 
    base_url="https://models.inference.ai.azure.com/",
)

chat_service = OpenAIChatCompletion(
    ai_model_id="gpt-4o-mini",
    async_client=client,
)

print("✅ Azure OpenAI service configured")
# Out:
# ✅ Azure OpenAI service configured

# %%
class ScratchpadPlugin:
    """Plugin for managing agent scratchpad - a persistent memory for user preferences and completed tasks"""
    
    def __init__(self, filepath: str = "agent_scratchpad.md"):
        self.filepath = Path(filepath)
        # Initialize scratchpad if it doesn't exist
        if not self.filepath.exists():
            self.filepath.write_text("# Agent Scratchpad\n\n## User Preferences\n\n## Completed Tasks\n\n")
    
    @kernel_function(
        description="Read the current agent scratchpad to get user's travel preferences and completed tasks"
    )
    def read_scratchpad(self) -> Annotated[str, "The contents of the agent scratchpad"]:
        """Read the current scratchpad contents"""
        return self.filepath.read_text()
    
    @kernel_function(
        description="Update the agent scratchpad with new user's travel preference or completed tasks"
    )
    def update_scratchpad(
        self,
        category: Annotated[str, "Category to update: 'preferences' or 'tasks'"],
        content: Annotated[str, "The new content to add"]
    ) -> Annotated[str, "Confirmation of the update"]:
        """Update the scratchpad with new information"""
        current_content = self.filepath.read_text()
        timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        
        if category.lower() == "preferences":
            # Find the preferences section and append
            lines = current_content.split("\n")
            for i, line in enumerate(lines):
                if "## User Preferences" in line:
                    lines.insert(i + 1, f"\n- [{timestamp}] {content}")
                    break
            current_content = "\n".join(lines)
        elif category.lower() == "tasks":
            # Find the tasks section and append
            lines = current_content.split("\n")
            for i, line in enumerate(lines):
                if "## Completed Tasks" in line:
                    lines.insert(i + 1, f"\n- [{timestamp}] {content}")
                    break
            current_content = "\n".join(lines)
        
        self.filepath.write_text(current_content)
        return f"✅ Scratchpad updated with {category}: {content}"

# Create the scratchpad plugin
scratchpad_plugin = ScratchpadPlugin("data/vacation_agent_scratchpad.md")
print("📝 Scratchpad plugin created")
# Out:
# 📝 Scratchpad plugin created

# %%
# Configure reduction parameters
REDUCER_TARGET_COUNT = 5  # Target number of messages to keep after reduction
REDUCER_THRESHOLD = 15    # Trigger reduction when message count exceeds this

# Create the history summarization reducer
history_reducer = ChatHistorySummarizationReducer(
    service=chat_service,
    target_count=REDUCER_TARGET_COUNT,
    threshold_count=REDUCER_THRESHOLD,
)

print(f"🔄 Chat History Reducer configured:")
print(f"   - Reduction triggered at: {REDUCER_THRESHOLD} messages")
print(f"   - Reduces history to: {REDUCER_TARGET_COUNT} messages")
# Out:
# 🔄 Chat History Reducer configured:
#    - Reduction triggered at: 15 messages
#    - Reduces history to: 5 messages

# %%
# Create the vacation planning agent with detailed instructions
agent = ChatCompletionAgent(
    service=chat_service,
    name="VacationPlannerAgent",
    instructions="""
    You are a helpful vacation planning assistant. Your job is to help users plan their perfect vacation.
    
    CRITICAL SCRATCHPAD RULES - YOU MUST FOLLOW THESE:
    1. FIRST ACTION: When starting ANY conversation, immedi ately call read_scratchpad() to check existing preferences
    2. AFTER LEARNING PREFERENCES: When user mentions ANY preference (destinations, activities, budget, dates), 
       immediately call update_scratchpad() with category 'preferences'
    3. AFTER COMPLETING TASKS: When you finish creating an itinerary or completing any task,
       immediately call update_scratchpad() with category 'tasks'
    4. BEFORE NEW ITINERARY: Always call read_scratchpad() before creating any itinerary
    
    EXAMPLES OF WHEN TO UPDATE SCRATCHPAD:
    - User says "I love beaches" → update_scratchpad('preferences', 'Loves beach destinations')
    - User says "budget is $3000" → update_scratchpad('preferences', 'Budget: $3000 per person for a week')
    - You create an itinerary → update_scratchpad('tasks', 'Created Bali itinerary for beach vacation')
    
    PLANNING PROCESS:
    1. Read scratchpad first
    2. Ask about preferences if not found
    3. Update scratchpad with new information
    4. Create detailed itineraries
    5. Update scratchpad with completed tasks
    
    BE EXPLICIT: Always announce when you're checking or updating the scratchpad.
    """,
    plugins=[scratchpad_plugin],
)

print("🤖 Vacation Planning Agent created with enhanced scratchpad instructions")
# Out:
# 🤖 Vacation Planning Agent created with enhanced scratchpad instructions

# %%
# Token tracking class
class TokenTracker:
    def __init__(self):
        self.history = []
        self.total_usage = CompletionUsage()
        self.reduction_events = []  # Track when reductions occur

    def add_usage(self, usage: CompletionUsage, message_num: int, thread_length: int = None):
        if usage:
            self.total_usage += usage
            entry = {
                "message_num": message_num,
                "prompt_tokens": usage.prompt_tokens,
                "completion_tokens": usage.completion_tokens,
                "total_tokens": usage.prompt_tokens + usage.completion_tokens,
                "cumulative_tokens": self.total_usage.prompt_tokens + self.total_usage.completion_tokens,
                "thread_length": thread_length
            }
            self.history.append(entry)

    def mark_reduction(self, message_num: int):
        self.reduction_events.append(message_num)

    def display_chart(self):
        """Display a chart showing token usage per message and the impact of reduction"""
        if not self.history:
            return

        html = "<div style='font-family: monospace; background: #2d2d2d; color: #f0f0f0; padding: 15px; border-radius: 8px; border: 1px solid #444;'>"
        html += "<h4 style='color: #4fc3f7; margin-top: 0;'>📊 Token Usage Analysis</h4>"
        html += "<pre style='color: #f0f0f0; margin: 0;'>"

        # Show prompt tokens per message to see reduction impact
        html += "<span style='color: #81c784;'>Prompt Tokens per Message (shows conversation context size):</span>\n"
        max_prompt = max(h["prompt_tokens"] for h in self.history)
        scale = 50 / max_prompt if max_prompt > 0 else 1

        for i, h in enumerate(self.history):
            bar_length = int(h["prompt_tokens"] * scale)
            bar = "█" * bar_length
            reduction_marker = " <span style='color: #ff6b6b;'>← REDUCTION!</span>" if h[
                "message_num"] in self.reduction_events else ""
            html += f"<span style='color: #aaa;'>Msg {h['message_num']:2d}:</span> <span style='color: #4fc3f7;'>{bar}</span> <span style='color: #ffd93d;'>{h['prompt_tokens']:,} tokens</span>{reduction_marker}\n"

        html += "\n</pre></div>"
        display(HTML(html))

        # Calculate reduction impact
        if self.reduction_events:
            # Find the message before and after first reduction
            first_reduction_msg = self.reduction_events[0]
            before_reduction = None
            after_reduction = None

            for h in self.history:
                if h["message_num"] == first_reduction_msg - 1:
                    before_reduction = h["prompt_tokens"]
                elif h["message_num"] == first_reduction_msg:
                    after_reduction = h["prompt_tokens"]

            if before_reduction and after_reduction:
                reduction_amount = before_reduction - after_reduction
                reduction_percent = (reduction_amount / before_reduction * 100)
                print(f"\n🔄 Actual Reduction Impact:")
                print(f"Prompt tokens before reduction: {before_reduction:,}")
                print(f"Prompt tokens after reduction: {after_reduction:,}")
                print(
                    f"Tokens saved: {reduction_amount:,} ({reduction_percent:.1f}%)")

# Display function for clean output


def display_message(role: str, content: str, color: str = "#2E8B57"):
    """Display a message with nice formatting that works in both light and dark themes"""
    # Use a semi-transparent background that adapts to the theme
    html = f"""
    <div style='
        margin: 10px 0; 
        padding: 12px 15px; 
        border-left: 4px solid {color}; 
        background: rgba(128, 128, 128, 0.1); 
        border-radius: 4px;
        color: inherit;
    '>
        <strong style='color: {color}; font-size: 14px;'>{role}:</strong><br>
        <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>{content}</div>
    </div>
    """
    display(HTML(html))


# Initialize token tracker
token_tracker = TokenTracker()
print("📊 Token tracking initialized")
# Out:
# 📊 Token tracking initialized

# %% [markdown]
# ## Run the Vacation Planning Conversation
# Now let's run through a complete conversation demonstrating:
#
# * Initial planning request
# * Preference gathering
# * Itinerary creation
# * Location change
# * Chat history reduction
# * Scratchpad usage

# %%
# Define the conversation flow
user_inputs = [
    "I'm thinking about planning a vacation. Can you help me?",
    "I love beach destinations with great food and culture. I enjoy water sports, exploring local markets, and trying authentic cuisine. My budget is around $3000 per person for a week.",
    "That sounds perfect! Please create a detailed itinerary for Bali.",
    "Actually, I've changed my mind. I'd prefer to go to the Greek islands instead. Can you create a new itinerary?",
    "What's the weather like there?",
    "What should I pack?",
    "Are there any cultural customs I should know about?",
    "What's the best way to get around?"
]


async def run_vacation_planning():
    """Run the vacation planning conversation with token tracking and history reduction"""

    # Create thread with history reducer
    thread = ChatHistoryAgentThread(chat_history=history_reducer)
    message_count = 0
    scratchpad_operations = 0  # Track scratchpad usage

    print("🚀 Starting Vacation Planning Session\n")

    # Process conversation
    for i, user_input in enumerate(user_inputs):
        message_count += 1
        display_message("User", user_input, "#4fc3f7")  # Blue for user

        # Get agent response
        full_response = ""
        usage = None
        function_calls = []  # Track function calls

        async for response in agent.invoke(
            messages=user_input,
            thread=thread,
        ):
            if response.content:
                full_response += str(response.content)
            if response.metadata.get("usage"):
                usage = response.metadata["usage"]
            thread = response.thread

        display_message(f"{agent.name}", full_response,
                        "#81c784")  # Green for agent

        # Track tokens with thread length
        if usage:
            token_tracker.add_usage(usage, message_count, len(thread))

        # Check thread status and look for scratchpad operations
        print(f"📝 Thread has {len(thread)} messages")

        # Count scratchpad operations in this turn
        turn_scratchpad_ops = 0
        async for msg in thread.get_messages():
            if hasattr(msg, 'content') and msg.content:
                content_str = str(msg.content)
                if 'read_scratchpad' in content_str or 'update_scratchpad' in content_str:
                    turn_scratchpad_ops += 1

        if turn_scratchpad_ops > scratchpad_operations:
            print(
                f"   📝 Scratchpad operations detected: {turn_scratchpad_ops - scratchpad_operations} new operations")
            scratchpad_operations = turn_scratchpad_ops

        # Show message types for first message
        if i == 0:
            message_types = []
            async for msg in thread.get_messages():
                msg_type = msg.role.value if hasattr(
                    msg.role, 'value') else str(msg.role)
                message_types.append(msg_type)
            print(f"   Message types: {message_types[:10]}..." if len(
                message_types) > 10 else f"   Message types: {message_types}")

        # Check if reduction should happen
        if len(thread) > REDUCER_THRESHOLD:
            print(
                f"   ⚠️ Thread length ({len(thread)}) exceeds threshold ({REDUCER_THRESHOLD})")

            # Attempt reduction
            is_reduced = await thread.reduce()
            if is_reduced:
                print(
                    f"\n🔄 HISTORY REDUCED! Thread now has {len(thread)} messages\n")
                token_tracker.mark_reduction(message_count + 1)

                # Show summary if available
                async for msg in thread.get_messages():
                    if msg.metadata and msg.metadata.get("__summary__"):
                        display_message("System Summary", str(
                            msg.content), "#ff6b6b")
                        break

    # Display final token usage chart
    print("\n--- Token Usage Analysis ---")
    token_tracker.display_chart()

    # Show final scratchpad contents
    print("\n--- Final Scratchpad Contents ---")
    scratchpad_contents = scratchpad_plugin.read_scratchpad()
    display(Markdown(scratchpad_contents))

    print(f"\n📊 Total scratchpad operations: {scratchpad_operations}")

    return thread

# Run the conversation
thread = await run_vacation_planning()
# Out:
# 🚀 Starting Vacation Planning Session
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>I'm thinking about planning a vacation. Can you help me?</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>I'm here to help you plan your vacation! Since I currently don't have any preferences noted down, could you please share what kind of vacation you're considering? For example, do you have any specific destinations in mind, activities you enjoy, or a budget for the trip?</div>
#     </div>
# 📝 Thread has 4 messages
#    Message types: ['user', 'assistant', 'tool', 'assistant']
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>I love beach destinations with great food and culture. I enjoy water sports, exploring local markets, and trying authentic cuisine. My budget is around $3000 per person for a week.</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>I've noted your preferences: you love beach destinations with great food and culture, enjoy water sports, exploring local markets, and trying authentic cuisine. I've also recorded your budget of around $3000 per person for a week.
#
# Would you like me to suggest some specific beach destinations that fit your preferences?</div>
#     </div>
# 📝 Thread has 9 messages
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>That sounds perfect! Please create a detailed itinerary for Bali.</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>Here's a detailed itinerary for your week-long beach vacation in Bali:
#
# ### **Day 1: Arrival in Bali**
# - **Morning:** Arrive at Ngurah Rai International Airport (DPS). Transfer to your hotel in Seminyak.
# - **Afternoon:** Check-in and relax at the hotel.
# - **Evening:** Enjoy dinner at a beachfront restaurant like La Plancha, known for its vibrant atmosphere and local dishes.
#
# ### **Day 2: Beach Day & Water Sports**
# - **Morning:** Breakfast at the hotel. Head to Tanjung Benoa for water sports (jet skiing, banana boat, parasailing).
# - **Afternoon:** Lunch at a local warung (café) in Tanjung Benoa.
# - **Evening:** Visit Uluwatu Temple, watch the traditional Kecak dance at sunset, and have dinner at a cliffside restaurant.
#
# ### **Day 3: Cultural Exploration**
# - **Morning:** Visit the traditional market in Ubud. Explore local crafts and try street food.
# - **Afternoon:** Lunch at a local café in Ubud. Visit the Tegalalang Rice Terrace and go for a short trek.
# - **Evening:** Dinner at a restaurant offering traditional Balinese cuisine, such as Bebek Tepi Sawah.
#
# ### **Day 4: Island Excursion**
# - **Morning:** Take a day trip to Nusa Penida. Visit Kelingking Beach and Broken Beach.
# - **Afternoon:** Enjoy lunch at a local café on Nusa Penida, followed by snorkeling at Crystal Bay.
# - **Evening:** Return to Bali and have dinner at your hotel or a nearby restaurant.
#
# ### **Day 5: Relaxation and Spa**
# - **Morning:** Relaxing beach day at Seminyak Beach.
# - **Afternoon:** Treat yourself to a Balinese spa experience (many include massages and traditional treatments).
# - **Evening:** After your spa treatment, enjoy dinner at Potato Head Beach Club, known for its lively atmosphere and beach view.
#
# ### **Day 6: Local Markets & Cooking Class**
# - **Morning:** Visit the Seminyak Village for shopping and exploring local boutiques.
# - **Afternoon:** Participate in a Balinese cooking class where you learn to prepare traditional dishes.
# - **Evening:** Enjoy the meal you prepared during the cooking class.
#
# ### **Day 7: Departure**
# - **Morning:** Leisurely breakfast and maybe one last dip in the sea.
# - **Afternoon:** Check out and transfer to the airport for your departure.
#
# ### **Budget Overview**
# - **Accommodations:** $1000 (approx. $150/night)
# - **Food & Dining:** $700 ($100/day)
# - **Activities & Water Sports:** $800
# - **Transport (including airport transfers):** $200
# - **Miscellaneous (shopping, spa):** $300
#
# **Total Estimate:** $3000 per person
#
# Feel free to adjust any part of the itinerary to better suit your preferences! Let me know if you have any changes or need further assistance.</div>
#     </div>
# 📝 Thread has 15 messages
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>Actually, I've changed my mind. I'd prefer to go to the Greek islands instead. Can you create a new itinerary?</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>Here's a detailed itinerary for your week-long vacation in the Greek islands:
#
# ### **Day 1: Arrival in Santorini**
# - **Morning:** Arrive at Santorini (Thira) International Airport. Transfer to your hotel in Oia.
# - **Afternoon:** Check-in and relax by the pool or explore Oia's charming streets.
# - **Evening:** Enjoy dinner with a sunset view at a restaurant like Sunset Ammoudi.
#
# ### **Day 2: Explore Santorini**
# - **Morning:** Visit the ancient ruins of Akrotiri. Learn about the Minoan civilization.
# - **Afternoon:** Relax at Red Beach and have lunch at a nearby taverna.
# - **Evening:** Explore Fira, the capital, and enjoy dinner with caldera views.
#
# ### **Day 3: Island Hopping to Mykonos**
# - **Morning:** Take a ferry to Mykonos (approx. 2 hours). Check in at your hotel.
# - **Afternoon:** Explore Mykonos Town. Visit the iconic windmills and Little Venice.
# - **Evening:** Dinner in Mykonos Town, followed by nightlife at one of the beach clubs.
#
# ### **Day 4: Beach Day in Mykonos**
# - **Morning:** Relax at one of Mykonos' famous beaches (e.g., Paradise Beach).
# - **Afternoon:** Enjoy water sports like jet skiing or paddleboarding.
# - **Evening:** Dinner at a beachfront restaurant, savoring fresh seafood.
#
# ### **Day 5: Day Trip to Delos**
# - **Morning:** Take a boat trip to Delos, a UNESCO World Heritage site. Explore the ancient ruins and museum.
# - **Afternoon:** Return to Mykonos for lunch and relaxation.
# - **Evening:** Have dinner at a local taverna and explore the vibrant nightlife.
#
# ### **Day 6: Travel to Naxos**
# - **Morning:** Take a ferry to Naxos (approx. 1 hour). Check into your hotel.
# - **Afternoon:** Visit the Portara (Temple of Apollo) and enjoy lunch by the harbor.
# - **Evening:** Explore Naxos Town and have dinner at a local taverna.
#
# ### **Day 7: Relax and Departure**
# - **Morning:** Enjoy a leisurely breakfast and some last-minute shopping.
# - **Afternoon:** Relax at a nearby beach, such as Agios Prokopios.
# - **Evening:** Transfer to the airport or ferry port for your departure.
#
# ### **Budget Overview**
# - **Accommodations:** $1000 (approx. $150/night)
# - **Food & Dining:** $700 ($100/day)
# - **Ferry transport:** $300 (between islands)
# - **Activities & Excursions:** $800
# - **Miscellaneous (shopping, leisure activities):** $200
#
# **Total Estimate:** $3000 per person
#
# This itinerary offers a blend of relaxing beach time and cultural exploration across the stunning Greek islands. Let me know if you want to make any adjustments or need more information!</div>
#     </div>
# 📝 Thread has 21 messages
#    ⚠️ Thread length (21) exceeds threshold (15)
#
# 🔄 HISTORY REDUCED! Thread now has 7 messages
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #ff6b6b;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #ff6b6b; font-size: 14px;'>System Summary:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>The user expressed a desire to plan a beach vacation focused on food, culture, water sports, and local markets, with a budget of around $3000 per person for a week. The assistant suggested a detailed itinerary for a week in Bali, covering various activities, dining options, and cultural experiences. Highlights included water sports in Tanjung Benoa, visiting Uluwatu Temple, exploring Ubud, a day trip to Nusa Penida, and a cooking class. The budget overview estimated expenses for accommodations, food, activities, transport, and miscellaneous costs. The user can adjust the itinerary as needed and seek further assistance.</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>What's the weather like there?</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>The weather in the Greek Islands typically varies depending on the time of year, but here’s a general overview:
#
# ### **Spring (March to May)**
# - **Temperature:** 15°C to 25°C (59°F to 77°F)
# - **Weather:** Pleasant and mild with some sunny days. Ideal for exploring and less crowded.
#
# ### **Summer (June to August)**
# - **Temperature:** 25°C to 35°C (77°F to 95°F)
# - **Weather:** Hot and sunny, perfect for beach activities. This is peak tourist season, so popular areas might be crowded.
#
# ### **Fall (September to November)**
# - **Temperature:** 20°C to 30°C (68°F to 86°F)
# - **Weather:** Warm and comfortable with decreasing crowds. September is still quite warm, while October starts to cool down.
#
# ### **Winter (December to February)**
# - **Temperature:** 10°C to 15°C (50°F to 59°F)
# - **Weather:** Cooler and wetter. Many businesses may close, and it’s not ideal for beach activities, but the islands are quiet and peaceful.
#
# The best time to visit for warm weather and beach activities is generally from late spring to early fall. If you have specific dates in mind, I can give you a more accurate forecast for that period!</div>
#     </div>
# 📝 Thread has 9 messages
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>What should I pack?</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>Here’s a packing list for your trip to the Greek islands, considering warm weather and beach activities:
#
# ### **Clothing**
# - **Lightweight Clothing:** T-shirts, tank tops, and light dresses for warm days.
# - **Swimwear:** At least 2-3 swimsuits for beach and pool time.
# - **Cover-Up:** For going to and from the beach.
# - **Sundresses or Shorts:** Comfortable for exploring.
# - **Light Jacket or Sweater:** For cooler evenings, especially near the coast.
# - **Flip-Flops or Sandals:** For the beach and casual outings.
# - **Comfortable Walking Shoes:** For exploring towns and archaeological sites.
#
# ### **Accessories**
# - **Sun Hat:** To protect yourself from the sun.
# - **Sunglasses:** With UV protection.
# - **Beach Bag:** To carry your essentials to the beach.
# - **Reusable Water Bottle:** To stay hydrated while exploring.
#
# ### **Personal Items**
# - **Sunscreen:** High SPF to protect your skin.
# - **Travel Toiletries:** Shampoo, conditioner, body wash, and personal hygiene items.
# - **First Aid Kit:** Basic items like band-aids, pain relievers, and any prescriptions.
#
# ### **Electronics**
# - **Camera:** To capture memories.
# - **Phone and Charger:** Consider a portable charger for long day trips.
# - **Adapters:** If your chargers don’t match European outlets.
#
# ### **Documents**
# - **Passport:** Check expiration and any visa requirements.
# - **Travel Insurance Documents:** Always good to have on hand.
# - **Itinerary & Booking Confirmations:** For accommodations, ferries, and activities.
#
# ### **Optional Items**
# - **Snorkeling Gear:** If you plan to snorkel and prefer using your gear.
# - **Lightweight Backpack:** For day trips and excursions.
#
# Packing light, comfortable clothing and essentials will help you make the most of your trip to the Greek islands! Let me know if you need any more tips or information!</div>
#     </div>
# 📝 Thread has 11 messages
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>Are there any cultural customs I should know about?</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>Here are some cultural customs and etiquette tips to keep in mind while visiting the Greek islands:
#
# ### 1. **Greetings**
# - A friendly handshake is common for men and women when greeting. Close friends may greet each other with a kiss on both cheeks.
# - Use "Kalimera" (Good morning), "Kalispera" (Good evening), and "Kalo taxidi" (Have a good trip) as greetings.
#
# ### 2. **Dress Code**
# - While the Greek islands are quite laid-back, it’s respectful to dress modestly when visiting churches and monasteries. Women should cover their shoulders and wear longer skirts or pants, while men should avoid wearing shorts.
#
# ### 3. **Dining Etiquette**
# - When dining out, it's a common practice to share dishes, as family-style dining is popular.
# - It’s polite to wait for the host to invite you to begin eating.
# - Tipping is appreciated, usually around 5-10% of the bill, but it's not mandatory.
#
# ### 4. **Personal Space**
# - Greeks are generally warm and friendly, often standing close during conversations. Don't be surprised if they touch your arm or shoulder while speaking.
#
# ### 5. **Punctuality**
# - While there's a laid-back attitude towards time, especially on islands, try to be punctual for any tours or reservations.
#
# ### 6. **Respect for Traditions**
# - Greek Orthodox traditions play a significant role in daily life. Respect local beliefs, particularly during religious festivals or ceremonies.
#
# ### 7. **Photography**
# - Always ask for permission before taking photos of people, especially in rural areas or during religious events.
#
# ### 8. **Language**
# - While many Greeks speak English, making an effort to learn a few basic Greek phrases can be appreciated and shows respect for the culture.
#
# Having a respectful and open attitude toward local customs will enhance your experience in the Greek islands. Enjoy your trip! If you need any more information or tips, feel free to ask!</div>
#     </div>
# 📝 Thread has 13 messages
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>What's the best way to get around?</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>Here are some of the best ways to get around the Greek islands:
#
# ### 1. **Public Transport**
# - **Buses:** Many islands have a reliable bus system that connects popular towns and beaches. They're affordable and a good way to get around.
# - **Taxis:** Taxis are available but can be more expensive than buses. It's common to share a taxi with others going in the same direction if you're in a group.
#
# ### 2. **Rental Cars and Scooters**
# - **Rental Cars:** Renting a car gives you the freedom to explore remote areas. Make sure to book in advance, especially during peak tourist season.
# - **Scooters or ATVs:** A popular option for island hopping and exploring. They are fun to ride but be cautious about wearing helmets and following traffic rules.
#
# ### 3. **Bicycles**
# - Renting a bicycle is a great way to explore smaller islands or towns. It’s environmentally friendly and lets you enjoy the scenery at a slower pace.
#
# ### 4. **Ferries**
# - For island hopping, ferries are the most common mode of transportation. They connect major islands and are a scenic way to travel.
#
# ### 5. **Walking**
# - Many towns and villages are pedestrian-friendly. Walking is often the best way to explore quaint streets, markets, and local attractions.
#
# ### **Tips:**
# - **Check Schedules:** Bus and ferry schedules can vary, especially during the off-peak season, so always check times in advance.
# - **Book Ferries Early:** If you have a tight itinerary, it’s wise to book your ferry tickets ahead of time to secure your preferred travel times.
#
# Using a combination of these options will allow you to experience the beautiful landscapes and local life of the Greek islands thoroughly. Let me know if you need any more information or assistance with your plans!</div>
#     </div>
# 📝 Thread has 17 messages
#    ⚠️ Thread length (17) exceeds threshold (15)
#
# --- Token Usage Analysis ---
# <div style='font-family: monospace; background: #2d2d2d; color: #f0f0f0; padding: 15px; border-radius: 8px; border: 1px solid #444;'><h4 style='color: #4fc3f7; margin-top: 0;'>📊 Token Usage Analysis</h4><pre style='color: #f0f0f0; margin: 0;'><span style='color: #81c784;'>Prompt Tokens per Message (shows conversation context size):</span>
# <span style='color: #aaa;'>Msg  1:</span> <span style='color: #4fc3f7;'>█████████</span> <span style='color: #ffd93d;'>486 tokens</span>
# <span style='color: #aaa;'>Msg  2:</span> <span style='color: #4fc3f7;'>██████████████</span> <span style='color: #ffd93d;'>753 tokens</span>
# <span style='color: #aaa;'>Msg  3:</span> <span style='color: #4fc3f7;'>██████████████████</span> <span style='color: #ffd93d;'>1,004 tokens</span>
# <span style='color: #aaa;'>Msg  4:</span> <span style='color: #4fc3f7;'>█████████████████████████████████</span> <span style='color: #ffd93d;'>1,788 tokens</span>
# <span style='color: #aaa;'>Msg  5:</span> <span style='color: #4fc3f7;'>█████████████████████████</span> <span style='color: #ffd93d;'>1,356 tokens</span> <span style='color: #ff6b6b;'>← REDUCTION!</span>
# <span style='color: #aaa;'>Msg  6:</span> <span style='color: #4fc3f7;'>██████████████████████████████</span> <span style='color: #ffd93d;'>1,646 tokens</span>
# <span style='color: #aaa;'>Msg  7:</span> <span style='color: #4fc3f7;'>██████████████████████████████████████</span> <span style='color: #ffd93d;'>2,068 tokens</span>
# <span style='color: #aaa;'>Msg  8:</span> <span style='color: #4fc3f7;'>██████████████████████████████████████████████████</span> <span style='color: #ffd93d;'>2,667 tokens</span>
#
# </pre></div>
# 🔄 Actual Reduction Impact:
# Prompt tokens before reduction: 1,788
# Prompt tokens after reduction: 1,356
# Tokens saved: 432 (24.2%)
#
# --- Final Scratchpad Contents ---
# # Agent Scratchpad
#
# ## User Preferences
#
# - [2025-12-11 21:27:42] Changed destination preference to Greek islands.
#
# - [2025-12-11 21:27:28] Budget: $3000 per person for a week.
#
# - [2025-12-11 21:27:28] Loves beach destinations with great food and culture, enjoys water sports, exploring local markets, and trying authentic cuisine.
#
# ## Completed Tasks
#
# - [2025-12-11 21:27:43] Creating detailed itinerary for vacation in the Greek islands.
#
# - [2025-12-11 21:27:31] Creating detailed Bali itinerary for beach vacation.
# 📊 Total scratchpad operations: 0

# %%
# Analyze token usage
print("📊 Total Token Usage Summary\n")
print(f"Total Prompt Tokens: {token_tracker.total_usage.prompt_tokens:,}")
print(
    f"Total Completion Tokens: {token_tracker.total_usage.completion_tokens:,}")
print(
    f"Total Tokens Used: {token_tracker.total_usage.prompt_tokens + token_tracker.total_usage.completion_tokens:,}")

print("\n💡 Note: The reduction impact is shown in the chart above.")
print("Look for the dramatic drop in prompt tokens after the REDUCTION marker.")
print("This shows how chat history summarization reduces the context size for future messages.")
# Out:
# 📊 Total Token Usage Summary
#
# Total Prompt Tokens: 11,768
# Total Completion Tokens: 2,819
# Total Tokens Used: 14,587
#
# 💡 Note: The reduction impact is shown in the chart above.
# Look for the dramatic drop in prompt tokens after the REDUCTION marker.
# This shows how chat history summarization reduces the context size for future messages.
