# %% [markdown]
# Ref: https://github.com/microsoft/ai-agents-for-beginners/blob/main/08-multi-agent/code_samples/08-python-agent-framework.ipynb

# %%
# 🤖 Import Multi-Agent Workflow Components
# OpenAIChatClient: GitHub Models integration for agent communication
# WorkflowEvent, WorkflowBuilder: Core workflow orchestration classes
# WorkflowOutputEvent: Structured event handling for agent coordination
from agent_framework.openai import OpenAIChatClient
from agent_framework import WorkflowEvent, WorkflowBuilder, WorkflowOutputEvent
# 📦 Import Configuration and Environment Management
import os                      # Environment variable access for secure configuration
from dotenv import load_dotenv # Secure loading of API credentials and settings
# 🔧 Load Multi-Agent Workflow Configuration  
# Load environment variables for secure GitHub Models access
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID for agent communication
load_dotenv()
# Out:
# True

# %%
# 🔗 Initialize Shared Chat Client for Multi-Agent Communication
# Create a unified client that all agents in the workflow will use
# This ensures consistent API access and efficient resource utilization
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model for all agents in workflow
)

# %%
# 🎩 Agent 1: Hotel Concierge - Quality Reviewer Role
# This agent specializes in evaluating travel recommendations for authenticity
# Acts as the second stage in our multi-agent workflow for quality assurance
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an experienced hotel concierge who has strong opinions about providing the most local and authentic experiences for travelers.
    
    Your role in this multi-agent workflow:
    - Review travel recommendations from the Front Desk agent
    - Assess whether suggestions provide authentic, non-touristy experiences
    - Approve recommendations that meet high standards for local authenticity
    - Provide constructive feedback for refinement without giving specific examples
    
    Always focus on the quality and authenticity of experiences rather than just popular tourist destinations.
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
writer_agent    = chat_client.create_agent(
        instructions=(
           REVIEWER_INSTRUCTIONS
        ),
        name=REVIEWER_NAME,
    )

agent_reviewer = chat_client.create_agent(
        instructions=(
            FRONTDESK_INSTRUCTIONS
        ),
        name=FRONTDESK_NAME,
    )

# %%
workflow = WorkflowBuilder().set_start_executor(writer_agent).add_edge(writer_agent, agent_reviewer).build()
# Out:
# Adding an edge with Executor or AgentProtocol instances directly is not recommended, because workflow instances created from the builder will share the same executor/agent instances. Consider using a registered name for lazy initialization instead.

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
event.__class__
# Out:
# agent_framework._workflows._events.WorkflowStatusEvent

# %%
async for event in workflow.run_stream("I would like to go to Paris."):
        # if isinstance(event, DatabaseEvent):
        #     print(f"{event}")
        # if isinstance(event, WorkflowOutputEvent):
        # print instance for the event
     
        print(f"Workflow instance {event.__class__} output: {event.data}")
# Out:
# Workflow instance <class 'agent_framework._workflows._events.WorkflowStartedEvent'> output: None
# Workflow instance <class 'agent_framework._workflows._events.WorkflowStatusEvent'> output: None
# Workflow instance <class 'agent_framework._workflows._events.ExecutorInvokedEvent'> output: I would like to go to Paris.
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: Your
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  enthusiasm
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  for
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  visiting
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  Paris
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  is
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  fantastic
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: !
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  To
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  make
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  the
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  most
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  of
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  your
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  trip
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: ,
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  I
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  urge
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  you
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  to
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  look
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  for
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  authentic
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  experiences
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  that
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  capture
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  the
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  heartfelt
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  essence
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  of
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  the
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  city
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: .
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  Seek
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  out
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  local
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  eateries
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  where
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  the
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  residents
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  dine
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: ,
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  explore
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  markets
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  vibrant
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  with
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  fresh
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  French
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  produce
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: ,
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  or
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  perhaps
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  attend
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  a
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  neighborhood
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  festival
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  or
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  event
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  that
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  showcases
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  the
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  local
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  culture
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: .
#
#
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: By
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  vent
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: uring
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  into
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  areas
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  like
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  the
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  quaint
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  streets
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  of
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  Rue
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  Cler
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  or
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  the
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  lively
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  vibe
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  of
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  the
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  Canal
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  Saint
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: -Mart
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: in
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: ,
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  you're
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  bound
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  to
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  discover
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  the
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  true
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  Paris
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  outside
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  of
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  the
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  tourist
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  trap
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: .
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  Should
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  you
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  have
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  specific
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  plans
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  or
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  ideas
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  in
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  mind
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: ,
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  please
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  share
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: ,
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  and
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  I'll
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  be
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  glad
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  to
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  provide
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  insight
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  into
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  their
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  authenticity
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  and
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  help
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  you
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  refine
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  your
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  itinerary
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: !
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:
# Workflow instance <class 'agent_framework._workflows._events.ExecutorCompletedEvent'> output: [AgentExecutorResponse(executor_id='Concierge', agent_run_response=<agent_framework._types.AgentRunResponse object at 0x10f333040>, full_conversation=[<agent_framework._types.ChatMessage object at 0x10f2d3a90>, <agent_framework._types.ChatMessage object at 0x10f331210>])]
# Workflow instance <class 'agent_framework._workflows._events.SuperStepStartedEvent'> output: None
# Workflow instance <class 'agent_framework._workflows._events.ExecutorInvokedEvent'> output: AgentExecutorResponse(executor_id='Concierge', agent_run_response=<agent_framework._types.AgentRunResponse object at 0x10f333040>, full_conversation=[<agent_framework._types.ChatMessage object at 0x10f2d3a90>, <agent_framework._types.ChatMessage object at 0x10f331210>])
# No outgoing edges found for executor FrontDesk; dropping messages.
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: Explore
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  the
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  Canal
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  Saint
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: -Mart
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: in
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  area
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  for
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  a
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  mix
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  of
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  charming
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  cafés
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: ,
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  boutiques
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: ,
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  and
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  a
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  local
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:  atmosphere
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output: .
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:
# Workflow instance <class 'agent_framework._workflows._events.AgentRunUpdateEvent'> output:
# Workflow instance <class 'agent_framework._workflows._events.ExecutorCompletedEvent'> output: [AgentExecutorResponse(executor_id='FrontDesk', agent_run_response=<agent_framework._types.AgentRunResponse object at 0x1088b6140>, full_conversation=[<agent_framework._types.ChatMessage object at 0x10f2d3a90>, <agent_framework._types.ChatMessage object at 0x10f331210>, <agent_framework._types.ChatMessage object at 0x10f538cd0>])]
# Workflow instance <class 'agent_framework._workflows._events.SuperStepCompletedEvent'> output: None
# Workflow instance <class 'agent_framework._workflows._events.SuperStepStartedEvent'> output: None
# Workflow instance <class 'agent_framework._workflows._events.SuperStepCompletedEvent'> output: None
# Workflow instance <class 'agent_framework._workflows._events.WorkflowStatusEvent'> output: None
