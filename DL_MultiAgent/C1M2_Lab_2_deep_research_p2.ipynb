# %% [markdown]
# # Automatic Deep Research - Adding custom tools
#
# Welcome to the second practice lab of this module!
#
# In this lab, you will continue working on the deep research crew from Lesson 1. This time you will be writing you own custom tools, and adding them to your agents so that they can give more accurate responses.
#
# **What you'll learn:**
# - How to create custom tools for your agents
#
# ## Background
#
# As a research consultant, you're constantly tasked with producing comprehensive reports on diverse topics for demanding clients. You need to build an AI research crew that can rapidly gather, verify, and synthesize information from across the internet, delivering reliable, fact-checked reports that meet tight deadlines and exacting standards regardless of the subject matter.
#
# ## General instructions
# In this lab you will be presented with a structure of the code, but you will need to complete some of it.
#
# To successfully run this lab, replace all instances of the placeholder `None` with your own code. Sections where you need to write code will be delimited between `### START CODE HERE ###` and `### END CODE HERE ###`.
#
# **<font color='#5DADEC'>Please make sure to save your work periodically, so you don't lose any progress.</font>**

# %% [markdown]
# ## Table of contents
#
# - [1. Problem statement](#1)
# - [2. Set up your notebook](#2)
# - [3. Tools](#3)
# - [4. Agents](#4)
# - [5. Guardrails](#5)
# - [6. Tasks](#6)
# - [7. Execution hooks](#7)
# - [8. Crew](#8)
#   - [8.1. Define the crew](#8-1)
#   - [8.2. Define the inputs](#8-2)
#   - [8.3. Run the crew](#8-3)

# %% [markdown]
# <a id="1"></a>
#
# ## 1. Problem statement
#
# The goal of this lab is to take the multi-agent system that can interpret a user's input, and create an action plan, then do the actual research and fact checking, and finally output a report you can share with the client, and add tools to the agents so they can be better at achieving their goals.
#
# You will reuse the code from the first practice lab of this module, so you only need to write new code in the sections [Tools](#3), [Agents](#4), [Tasks](#6) and [Define the inputs](#8.2), the rest of the lab remains the same, with the solution to the previous lab already given to you.
#
# Here is a visual summary of the structure of your crew, as well as the new elements you will be adding:
#
# <img src="../images/lab2-agents-tasks-diagram.png">

# %% [markdown]
# <a id="2"></a>
#
# ## 2. Set up your notebook
#
# Begin by setting up the notebook by importing all necessary modules, and configuring the environment variables so you can connect to OpenAI.

# %%
from crewai import Agent, Task, Crew, LLM
from crewai_tools import EXASearchTool, ScrapeWebsiteTool
import os
os.environ["CREWAI_TESTING"] = "true"
from utils import get_openai_api_key, get_exa_api_key
from IPython.display import Markdown
import yaml

# set the OpenAI model (gpt-4o-mini)
os.environ["MODEL"] = "gpt-4o-mini"
# set up the OpenAI API key 
os.environ["OPENAI_API_KEY"] = get_openai_api_key()
# set the exa API key
os.environ["EXA_API_KEY"] = get_exa_api_key()

# %% [markdown]
# <a id="3"></a>
#
# ## 3. Tools
#
# The final goal of this Crew you've been building during the course is to provide the user with a complete report containing researched information about a topic, and what is a report without some cool graphics?
#
# In the next cell, you will be writing a custom tool that automatically creates charts based on a report of gathered information. This tool will be added to the **Report Writer** agent, so it can add visualization into the final report.
#
# Remember that the base structure for a custom tool is
# ```python
# class MyCustomTool(BaseTool):
#     name: str = "Name of my tool"
#     description: str = "What this tool does. It's vital for effective utilization."
#     args_schema: Type[BaseModel] = {}
#
#     def _run(self, argument: str) -> str:
#         # Your tool's logic here
#         return "Tool's result"
# ```
#
# In this case, you will need to complete the `CustomPlotTool` class with:
# - `name`: a suitable name for the tool
# - `description`: This should be a detailed description of the tool. Mention:
#     - The expected input: the full validated information, as a string
#     - What it does: automatically generates plots from text
# - `_run()` function: specify the type of input and output expected by the tool
#
# The code for generating the plots is already given to you.

# %%
# import packages needed for the custom tool
from crewai.tools import BaseTool
from crewai import LLM
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import json

# Define the custom tool for creating plots
class CustomPlotTool(BaseTool):
    ### START CODE HERE ###
    name: None="Custom tool"
    description: None="Custom tool"
    def _run(self, research: None) -> str:
    ### END CODE HERE ###
        try:
            extraction_prompt = f"""
            You are an expert data visualization assistant. Analyze the provided research text and identify meaningful, insightful charts that can be created to visualize quantifiable data supporting the research's key insights and findings. Only suggest charts for data that includes numerical values, measurable trends, comparisons, or categorical distributions that can be effectively plotted.

            Focus on creating visualizations that highlight trends, comparisons, distributions, or relationships that add value to the research. Avoid suggesting charts for purely qualitative or non-quantifiable information.

            For each chart, provide a JSON object with:
              - "chart_type" (string: choose from "line" for trends over time/continuous, "bar" for comparisons, "histogram" for distributions, "scatter" for relationships, "pie" for proportions)
              - "x_axis" (string: variable name for x-axis, e.g., "year", "category")
              - "y_axis" (string: variable name for y-axis, e.g., "value", "count")
              - "color" (string: optional variable for color grouping/hue, or null if not applicable)
              - "Title" (string: descriptive, insightful title that explains what the chart shows)
              - "data" (dictionary: keys matching x_axis, y_axis, and color variables; values as lists of extracted numerical/categorical data from the research)

            Ensure data is accurately extracted and formatted as lists. If a variable has multiple series (e.g., for color), include all in the data dictionary.

            If no quantifiable data suitable for meaningful visualization is present in the research, return an empty array [].

            Text:
            {research}

            Example output (return valid JSON only):
            [
              {{"chart_type": "line", "x_axis": "year", "y_axis": "funding_amount", "color": "sector", "Title": "AI Research Funding Trends by Sector", "data": {{"year": [2020, 2021, 2022], "funding_amount": [2.5, 3.8, 5.2], "sector": ["Healthcare", "Finance", "Tech"]}}}},
              {{"chart_type": "bar", "x_axis": "tool_name", "y_axis": "adoption_rate", "color": null, "Title": "Market Adoption Rates of AI Tools", "data": {{"tool_name": ["ToolA", "ToolB", "ToolC"], "adoption_rate": [45, 67, 23]}}}}
            ]

            Return only the JSON array, no additional text or explanations.
            """
            llm = LLM(model="gpt-4o-mini",)  # Initialize the LLM instance
            llm_response = llm.call([{"role": "user", "content": extraction_prompt}])

            # Clean the response to extract just the JSON part
            llm_response = llm_response.strip()
            if llm_response.startswith('```json'):
                llm_response = llm_response[7:]  # Remove ```json
            if llm_response.endswith('```'):
                llm_response = llm_response[:-3]  # Remove ```
            llm_response = llm_response.strip()

            # --- Step 2: Parse the LLM output ---
            charts_data = json.loads(llm_response)

            if not isinstance(charts_data, list) or len(charts_data) == 0:
                return "No information found in the research to visualize."

            plots_created = []

            # --- Step 3: Create plots for each chart ---
            for i, chart_info in enumerate(charts_data):
                try:
                    # Extract chart configuration
                    chart_type = chart_info.get("chart_type", None).lower()
                    x_axis = chart_info.get("x_axis", "x")
                    y_axis = chart_info.get("y_axis", "y") 
                    title = chart_info.get("Title", f"Chart {i+1}")
                    hue = chart_info.get("color", None)
                    data = chart_info.get("data", {})

                    # Create DataFrame from the data
                    df = pd.DataFrame(data)

                    if df.empty:
                        continue

                    # Create the plot
                    plt.figure(figsize=(10, 6))

                    if chart_type == "line":
                        sns.lineplot(data=df, x=x_axis, y=y_axis, marker="o", hue=hue)
                    elif chart_type in ["bar", "column"]:
                        sns.barplot(data=df, x=x_axis, y=y_axis, hue=hue)
                    elif chart_type == "histogram":
                        plt.hist(df[y_axis], bins=10, alpha=0.7, hue=hue)
                        plt.xlabel(y_axis)
                        plt.ylabel("Frequency")
                    elif chart_type == "scatter":
                        # Default to scatter plot
                        sns.scatterplot(data=df, x=x_axis, y=y_axis, hue=hue)
                    elif chart_type == "pie":
                        # For pie chart, assume y_axis is values, x_axis is labels
                        plt.pie(df[y_axis], labels=df[x_axis], autopct='%1.1f%%', startangle=90)
                        plt.title(title)
                        plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

                    plt.title(title)
                    plt.xticks(rotation=45)
                    plt.tight_layout()

                    # --- Step 4: Save the plot ---
                    os.makedirs("plots", exist_ok=True)
                    filename = f"plots/plot_{i+1}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.png"
                    plt.savefig(filename, dpi=300, bbox_inches='tight')
                    plt.close()

                    plots_created.append(filename)

                except Exception as e:
                    print(f"Error creating chart {i+1}: {str(e)}")
                    continue

            if plots_created:
                return f"Successfully created {len(plots_created)} plots: {', '.join(plots_created)}"
            else:
                return "No plots could be created from the extracted data."

        except json.JSONDecodeError as e:
            return f"Error parsing LLM response as JSON: {str(e)}"
        except Exception as e:
            return f"Error generating smart plot: {str(e)}"

# %% [markdown]
# As in the previous labs, you will still use the web search and scraping tools for the **Internet Researcher** and **Fact Checker** agents, which you will initialize in the next cell

# %%
# create tools instances
exa_search_tool = EXASearchTool(base_url=os.getenv("EXA_BASE_URL"))
scrape_website_tool = ScrapeWebsiteTool()

# %% [markdown]
# <a id="4"></a>
#
# ## 4. Agents
#
# For this system, you will use four agents:
# - Research Planner
# - Internet Researcher
# - Fact checker
# - Report Writer
#
# All their arguments (`role`, `goal`, `backstory`) are already given to you in a YAML file, which you will use to configure the agents. If you want to take a closer look go to the [config/agents.yaml](config/agents.yaml) file on the file navigator on the left.
#
# Don't forget to add the new custom tool to the **Report Writer** agent!

# %%
# load the configuration file for the agents
with open('config/agents.yaml', 'r') as file:
        agent_config = yaml.safe_load(file)


# create the agents using the configuration
research_planner = Agent(
        config=agent_config['research_planner'],
        verbose=True
        )

internet_researcher = Agent( 
        config=agent_config['internet_researcher'],
        verbose=True,
        tools=[exa_search_tool, scrape_website_tool]
        )

fact_checker = Agent(
        config=agent_config['fact_checker'],
        verbose=True,
        tools=[exa_search_tool, scrape_website_tool]
        )
report_writer = Agent(
        config=agent_config['report_writer'],
        verbose=True,
        ### START CODE HERE ### 
        # add the automatic plot tool
        tools=[CustomPlotTool()]
        ### END CODE HERE ###
        )

# %% [markdown]
# <a id="5"></a>
#
# ## 5. Guardrails
#
# To make your system more robust, you want to add guardrails to your tasks. These guardrails provide a way to validate and transform task outputs before they are passed to the next task, helping ensure data quality and providing feedback to agents when their output doesn't meet specific criteria. You can find out more about guardrails in the [docs](https://docs.crewai.com/en/concepts/tasks#task-guardrails).
#
#
# In particular, you will implement a guardrail for the final output. You want to make sure the final report has all the sections needed:
# - Summary
# - Insights (or recommendations)
# - Citations (or References)

# %%
import re

# write the custom guardrail function
def write_report_guardrail(output):
    # get the raw output from the TaskOutput object
    try:
        output = output if type(output)==str else output.raw 
    except Exception as e:
        return (False, ("Error retrieving the `raw` argument: "
                        f"\n{str(e)}\n"
                        )
                )
    
    # convert the output to lowercase
    output_lower = output.lower()

    # check that the summary section exists
    if not re.search(r'#+.*summary', output_lower):
        return (False, 
                "The report must include a Summary section with a header like '## Summary'"
                )

    # check that the insights or recommendations sections exist
    if not re.search(r'#+.*insights|#+.*recommendations', output_lower):
        return (False, 
                "The report must include an Insights section with a header like '## Insights'"
                )

    # check that the citations (or references) section exists
    if not re.search(r'#+.*citations|#+.*references', output_lower): 
        return (False, 
                "The report must include a Citations (or References) section with a header like '## Citations'"
                )
    return (True, output)

# %% [markdown]
# <a id="6"></a>
#
# ## 6. Tasks
# Now you are ready to create the tasks. Just as you did with the agents, you will load the configuration from a YAML file, which you can find in [`config/tasks.yaml`](config/tasks.yaml).
#
# In order to actually add the charts to the final report you will need to update the `write_final_report` task in the [`tasks.yaml`](config/tasks.yaml) file. Adapt the `description` and `expected_output` to include instructions include the charts generated by the custom tool.
#
# Once that's done, run the next cell to create each task. The agents, guardrails, and context are already defined.

# %%
# load the configuration file for the tasks
with open('config/tasks.yaml', 'r') as file:
    task_config = yaml.safe_load(file)


# create the tasks using the configuration
create_research_plan = Task( 
    config=task_config['create_research_plan'],
    agent=research_planner 
)

gather_research_data = Task(
    config=task_config['gather_research_data'],
    agent=internet_researcher,
)

verify_information_quality = Task(
    config=task_config['verify_information_quality'],
    agent=fact_checker, 
)

write_final_report = Task( 
    config=task_config['write_final_report'],
    agent=report_writer, 
    guardrails=[write_report_guardrail],
)

# %% [markdown]
# <a id="7"></a>
#
# ## 7. Execution hooks
#
# The last step before creating the Crew is creating an [after kickoff hook](https://docs.crewai.com/en/learn/before-and-after-kickoff-hooks#after-kickoff-hook).
#
# In this case, you will create a hook that takes the final output and saves it to a Markdown file on your local file system.

# %%
def save_file_hook(result):
    """
    Save the final research report to a local markdown file
    """
    try:
        # Get the final report content from the last task output
        if hasattr(result, 'tasks_output') and result.tasks_output:
            report_content = result.tasks_output[-1].raw
        else:
            report_content = str(result)
        
        filename = f"research_report-p2.md"
        
        # Save to file
        with open(filename, 'w', encoding='utf-8') as f:
            f.write(report_content)
        
        print(f"Report successfully saved to: {filename}")
        
    except Exception as e:
        print(f"Error saving report to file: {str(e)}")

# %% [markdown]
# <a id="8"></a>
#
# ## 8. Crew
#
# <a id="8-1"></a>
#
# ### 8.1. Define the crew
# Run the next cell to define the crew.

# %%
# Create the urban planning crew
deep_research_crew = Crew(
    # include all the agents
    agents=[research_planner, 
            internet_researcher, 
            fact_checker, 
            report_writer],
    # include all the tasks in the order to be executed
    tasks=[create_research_plan, 
           gather_research_data, 
           verify_information_quality, 
           write_final_report],
    # add memory to the crew
    memory=True,
    # add the after kickoff hook
    after_kickoff_callbacks=[save_file_hook]
)

# %% [markdown]
# <a id="8-2"></a>
#
# ### 8.2. Define the inputs
#
# Use the next cell to define the inputs to your Crew. This should represent the user's query. Try using the same query as in the previous lab, so you can compare the results.

# %%
### START CODE HERE ###

# write your query in the "user_query" value
inputs = { 
        "user_query": "how to be the best ceo?"
}
### END CODE HERE ###

# %% [markdown]
# <a id="8-3"></a>
#
# ### 8.3. Run the crew
# Now you can run, or kick off, the crew to get the result.

# %%
# Execute the crew's tasks
result = deep_research_crew.kickoff(inputs=inputs)
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Planner                                                                                        │
# │                                                                                                                 │
# │  Task: Break down the research query "how to be the best ceo?" into specific topics and key questions that      │
# │  need investigation. Create a focused research plan.                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Planner                                                                                        │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Research Plan: How to Be the Best CEO**                                                                      │
# │                                                                                                                 │
# │  **1) Main Research Topics to Investigate:**                                                                    │
# │                                                                                                                 │
# │     a. Leadership Qualities and Styles                                                                          │
# │     b. Strategic Decision-Making                                                                                │
# │     c. Effective Communication                                                                                  │
# │     d. Financial Acumen                                                                                         │
# │     e. Talent Management and Team Building                                                                      │
# │     f. Measuring Success and Performance                                                                        │
# │     g. Adaptability and Change Management                                                                       │
# │     h. Influence of Company Culture                                                                             │
# │                                                                                                                 │
# │  **2) Key Questions for Each Topic:**                                                                           │
# │                                                                                                                 │
# │     a. **Leadership Qualities and Styles**                                                                      │
# │        - What are the most effective leadership qualities exhibited by successful CEOs?                         │
# │        - How do various leadership styles (transformational, transactional, servant leadership, etc.) impact    │
# │  company performance?                                                                                           │
# │        - In what ways can a CEO develop their leadership skills over time?                                      │
# │                                                                                                                 │
# │     b. **Strategic Decision-Making**                                                                            │
# │        - What frameworks or models do top CEOs use for strategic decision-making?                               │
# │        - How do successful CEOs balance short-term gains and long-term sustainability?                          │
# │        - What processes do CEOs follow to evaluate risks and opportunities in decision-making?                  │
# │                                                                                                                 │
# │     c. **Effective Communication**                                                                              │
# │        - What communication strategies do successful CEOs employ to ensure alignment within the organization?   │
# │        - How important is public speaking and media engagement for a CEO?                                       │
# │        - In what ways does a CEO’s communication style affect employee morale and engagement?                   │
# │                                                                                                                 │
# │     d. **Financial Acumen**                                                                                     │
# │        - What financial metrics should a CEO prioritize to gauge company health?                                │
# │        - How do successful CEOs use financial data to drive operational decisions?                              │
# │        - What role does budget management play in effective CEO performance?                                    │
# │                                                                                                                 │
# │     e. **Talent Management and Team Building**                                                                  │
# │        - What methods do top CEOs utilize for recruiting and retaining talent?                                  │
# │        - How do successful CEOs foster a collaborative and inclusive workplace culture?                         │
# │        - What leadership techniques do CEOs use to develop the potential of their teams?                        │
# │                                                                                                                 │
# │     f. **Measuring Success and Performance**                                                                    │
# │        - What key performance indicators (KPIs) do successful CEOs track to measure their effectiveness?        │
# │        - How do the best CEOs define and evaluate their success?                                                │
# │        - In what ways do CEOs adjust their strategies based on performance outcomes?                            │
# │                                                                                                                 │
# │     g. **Adaptability and Change Management**                                                                   │
# │        - How do successful CEOs lead their organizations through periods of change?                             │
# │        - What strategies do top CEOs employ to remain competitive in fast-changing markets?                     │
# │        - How can CEOs create a culture that embraces innovation and adaptability?                               │
# │                                                                                                                 │
# │     h. **Influence of Company Culture**                                                                         │
# │        - How important is company culture in the effectiveness of a CEO?                                        │
# │        - What steps do successful CEOs take to shape and influence company culture?                             │
# │        - In what ways does a strong organizational culture contribute to overall business success?              │
# │                                                                                                                 │
# │  **3) Success Criteria for the Research:**                                                                      │
# │                                                                                                                 │
# │     - Comprehensive and diverse sources of information: successful CEOs' autobiographies, leadership books,     │
# │  industry reports, academic journals, and case studies.                                                         │
# │     - Identification of common traits and practices among highly effective CEOs across various industries.      │
# │     - Development of an actionable blueprint or framework that aspiring CEOs can follow to enhance their        │
# │  effectiveness.                                                                                                 │
# │     - A balanced view that accounts for both qualitative and quantitative assessments of successful CEO         │
# │  behaviors and strategies.                                                                                      │
# │     - Insights that are applicable to a range of businesses from startups to established corporations,          │
# │  ensuring broad relevance.                                                                                      │
# │                                                                                                                 │
# │  Using this research plan, I will be able to synthesize valuable insights that will help answer the question    │
# │  "how to be the best CEO?" effectively, leading to a deeper understanding and practical strategies for          │
# │  aspiring leaders.                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Internet Researcher                                                                                     │
# │                                                                                                                 │
# │  Task: Using the research plan, search the internet and scrape relevant websites to collect comprehensive       │
# │  information on all identified topics. Verify information across multiple sources and cite all sources used.    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Internet Researcher                                                                                     │
# │                                                                                                                 │
# │  Thought: Thought: I need to begin researching the first topic, "Leadership Qualities and Styles," focusing on  │
# │  effective leadership qualities exhibited by successful CEOs, various leadership styles and their impact on     │
# │  performance, and how CEOs can develop these skills over time.                                                  │
# │                                                                                                                 │
# │  Using Tool: EXASearchTool                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "search_query": "effective leadership qualities styles successful CEOs",                                     │
# │    "start_published_date": null,                                                                                │
# │    "end_published_date": null,                                                                                  │
# │    "include_domains": null                                                                                      │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Title: Understanding CEO Leadership Styles | Norwich University - Online                                       │
# │  URL: https://online.norwich.edu/online/about/resource-library/understanding-ceo-leadership-styles              │
# │  ID: https://online.norwich.edu/online/about/resource-library/understanding-ceo-leadership-styles               │
# │  Score: None                                                                                                    │
# │  Published Date: 2025-01-01T00:00:00.000Z                                                                       │
# │  Author:                                                                                                        │
# │  Image:                                                                                                         │
# │  https://online.norwich.edu/sites/default/files/2024-06/nu_msl_-_understanding_ceo_leadership_styles.jpg        │
# │  Favicon: https://online.norwich.edu/themes/custom/norwich/assets/favicons/favicon-32x32.png                    │
# │  Extras: None                                                                                                   │
# │  Subpages: None                                                                                                 │
# │  Text: [Skip to main site navigation](https://online.norwich.edu/online.norwich.edu#main-menu) [Skip to main    │
# │  content](https://online.norwich.edu/online.norwich.edu#main-content)                                           │
# │                                                                                                                 │
# │  [Directory](https://www.norwich.edu/people)                                                                    │
# │                                                                                                                 │
# │  - [Apply](https://norwich.my.site.com/OnlinePrograms/s/login/)                                                 │
# │  - [Request Info](https://online.norwich.edu/get-started-norwich-university)                                    │
# │  - [Contact Us](https://online.norwich.edu/online/about/contact-norwich-university-online)                      │
# │  - [Give](https://giving.norwich.edu/norwich-university-giving)                                                 │
# │                                                                                                                 │
# │  # Understanding CEO Leadership Styles                                                                          │
# │                                                                                                                 │
# │  ## Leadership Styles                                                                                           │
# │                                                                                                                 │
# │  Chief Executive Officers or CEOs require strong leadership skills to effectively guide their organizations in  │
# │  meeting their strategic mission and goals.  Every CEO leads in their own management approach.  Some CEO        │
# │  leadership styles are more effective than others, dependent on the environment and industry.  Great leaders    │
# │  don’t follow a set formula but embrace their own leadership philosophy.                                        │
# │                                                                                                                 │
# │  While CEO leadership styles and skills can be difficult to cultivate and understand, they’re crucial to        │
# │  success.                                                                                                       │
# │                                                                                                                 │
# │  Here’s what the CEO role entails and the different types of CEO leadership styles that professionals may       │
# │  choose to use to support their roles.                                                                          │
# │                                                                                                                 │
# │  ## What Does a CEO Do?                                                                                         │
# │                                                                                                                 │
# │  As a company’s highest-ranking executive, the CEO makes the major decisions that affect the business,          │
# │  establishing a company culture, managing operations, and allocating resources. T...                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Internet Researcher                                                                                     │
# │                                                                                                                 │
# │  Thought: Thought: I need to compile comprehensive insights on "Leadership Qualities and Styles," emphasizing   │
# │  effective leadership behaviors of successful CEOs, various leadership styles, and strategies for skill         │
# │  development in leadership.                                                                                     │
# │                                                                                                                 │
# │  Using Tool: Read website content                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "website_url":                                                                                               │
# │  "https://online.norwich.edu/online/about/resource-library/understanding-ceo-leadership-styles"                 │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  The following text is scraped website content:                                                                 │
# │  Understanding CEO Leadership Styles | Norwich University - Online                                              │
# │  Skip to main site navigation                                                                                   │
# │  Skip to main content                                                                                           │
# │  Information For                                                                                                │
# │  On-Campus Students                                                                                             │
# │  Online Students                                                                                                │
# │  Incoming Students                                                                                              │
# │  Alumni                                                                                                         │
# │  Parents & Families                                                                                             │
# │  Faculty & Staff                                                                                                │
# │  News & Events                                                                                                  │
# │  News: Norwich Reveille                                                                                         │
# │  Events                                                                                                         │
# │  Blogs                                                                                                          │
# │  The Record                                                                                                     │
# │  Special Events & Traditions                                                                                    │
# │  Commencement and Commissioning                                                                                 │
# │  Directory                                                                                                      │
# │  Apply                                                                                                          │
# │  Request Info                                                                                                   │
# │  Contact Us                                                                                                     │
# │  Give                                                                                                           │
# │  Online Programs & Certificates                                                                                 │
# │  Information For                                                                                                │
# │  On-Campus Students                                                                                             │
# │  Online Students                                                                                                │
# │  Incoming Students                                                                                              │
# │  Alumni                                                                                                         │
# │  Parents & Families                                                                                             │
# │  Faculty & Staff                                                                                                │
# │  News & Events                                                                                                  │
# │  News: Norwich Reveille                                                                                         │
# │  Events                                                                                                         │
# │  Blogs                                                                                                          │
# │  The Record                                                                                                     │
# │  Special Events & Traditions                                                                                    │
# │  Commencement and Commissioning                                                                                 │
# │  Directory                                                                                                      │
# │  Apply                                                                                                          │
# │  Request Info                                                                                                   │
# │  Contact Us                                                                                                     │
# │  Give                                                                                                           │
# │  About                                                                                                          │
# │  History of Making a Difference                                                                                 │
# │  Do You Need to Be in the Military?                                                                             │
# │  Research, Centers & Institutes                                                                                 │
# │  Accreditation & Recognition                                                                                    │
# │  Online FAQs                                                                                                    │
# │  Resource Library                                                                                               │
# │  Contact Us                                                                                                     │
# │  Programs                                                                                                       │
# │  Undergraduate Online Programs                                                                                  │
# │  Graduate Online Programs                                                                                       │
# │  Accelerated Master's                                                                                           │
# │  Graduate Certificates                                                                                          │
# │  Non-Credit Certificates                                                                                        │
# │  Admissions                                                                                                     │
# │  Undergraduate                                                                                                  │
# │  Graduate                                                                                                       │
# │  Professional Development and Certificate                                                                       │
# │  International Students                                                                                         │
# │  Transfer Credit - Undergraduate                                                                                │
# │  Transfer Credits - Graduate                                                                                    │
# │  Enroll as a Non-Degree Seeking Student                                                                         │
# │  Academic Calendar                                                                                              │
# │  Military                                                                                                       │
# │  Military Benefits                                                                                              │
# │  Student Support Services                                                                                       │
# │  Credit Transfer & Agreements                                                                                   │
# │  Joint Special Operations University Program                                                                    │
# │  Association of the U.S. Army                                                                                   │
# │  United States Service Academies                                                                                │
# │  Army Transfer Credits                                                                                          │
# │  Military, First Responders and Federal Discounts                                                               │
# │  Paying for Your Education                                                                                      │
# │  Tuition & Fees                                                                                                 │
# │  Undergraduate Financial Aid                                                                                    │
# │  Graduate Financial Aid                                                                                         │
# │  Financial Aid FAQs                                                                                             │
# │  Scholarships & Aid                                                                                             │
# │  Financial Aid Contacts                                                                                         │
# │  Make a Payment                                                                                                 │
# │  Norwich Experience                                                                                             │
# │  Norwich Stories                                                                                                │
# │  Technology Requirements                                                                                        │
# │  Strategies for Success                                                                                         │
# │  Honor Societies                                                                                                │
# │  Student Support                                                                                                │
# │  All Sites                                                                                                      │
# │  You are here                                                                                                   │
# │  Norwich.edu                                                                                                    │
# │  At Norwich University, you’ll find a community that believes that to try is to be brave. To struggle is to     │
# │  learn. And to succeed is to go beyond what you though...                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Internet Researcher                                                                                     │
# │                                                                                                                 │
# │  Thought: Thought: I need to gather additional insights on various perspectives about leadership qualities and  │
# │  styles used by CEOs to enrich the information gathered.                                                        │
# │                                                                                                                 │
# │  Using Tool: Read website content                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "website_url": "https://mostlovedworkplace.com/most-loved-ceos-leadership-traits-2025/"                      │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  The following text is scraped website content:                                                                 │
# │  Most Loved CEOs: 12 Leadership Traits That Win Employee Hearts in 2025                                         │
# │  Now Live : 2025 Global Most Loved Workplaces® — See the Top 100 Companies                                      │
# │  The 2025 America’s Top 100 is live. See the list →                                                             │
# │  Our Process                                                                                                    │
# │  Get Certified Platform and Insights Success Stories                                                            │
# │  Certified Companies                                                                                            │
# │  Resources                                                                                                      │
# │  Blog Leader Show Podcast Reports & Materials Transformation Brand Guidelines Banner Examples FAQs              │
# │  Contact                                                                                                        │
# │  Top Workplaces Lists                                                                                           │
# │  Global Lists                                                                                                   │
# │  Global Top 100 America’s Top 100 UK’s Top 100                                                                  │
# │  Most Loved CEOs For Career Advancement For Disabled Workers For Diversity For LGBTQ+ For Mental Health For     │
# │  Neurodiversity For Parents and Caregivers For Veterans For Volunteering For Wellness For Women For Young       │
# │  Professionals                                                                                                  │
# │  X                                                                                                              │
# │  Sign In                                                                                                        │
# │  Apply Now                                                                                                      │
# │  Apply Now                                                                                                      │
# │  Our Process                                                                                                    │
# │  Get Certified Platform and Insights Success Stories                                                            │
# │  Certified Companies                                                                                            │
# │  Resources                                                                                                      │
# │  Blog Leader Show Podcast Reports & Materials Transformation Brand Guidelines Banner Examples FAQs              │
# │  Contact                                                                                                        │
# │  Top Workplaces Lists                                                                                           │
# │  Global Lists                                                                                                   │
# │  Global Top 100 America’s Top 100 UK’s Top 100                                                                  │
# │  Most Loved CEOs For Career Advancement For Disabled Workers For Diversity For LGBTQ+ For Mental Health For     │
# │  Neurodiversity For Parents and Caregivers For Veterans For Volunteering For Wellness For Women For Young       │
# │  Professionals                                                                                                  │
# │  X                                                                                                              │
# │  Apply Now                                                                                                      │
# │  Contents                                                                                                       │
# │  hide                                                                                                           │
# │  Most Loved CEOs: 12 Leadership Traits That Win Employee Hearts in 2025                                         │
# │  What You’ll Learn:                                                                                             │
# │  The Science Behind Beloved Leadership                                                                          │
# │  The 12 Essential Traits of Most Loved CEOs                                                                     │
# │  Transforming Leadership Theory into Practice                                                                   │
# │  Quantifying Leadership Effectiveness                                                                           │
# │  Leadership Evolution in 2025                                                                                   │
# │  Common Questions About Becoming a Most Loved CEO                                                               │
# │  Embracing the Future of Beloved Leadership                                                                     │
# │  Most Loved CEOs: 12 Leadership Traits That Win Employee Hearts in 2025                                         │
# │  8 min. read. Love isn’t just a personal emotion – it’s the secret ingredient that transforms good leaders      │
# │  into unforgettable ones. In today’s rapidly evolving workplace, the most successful CEOs aren’t just measured  │
# │  by their business acumen,...                                                                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Internet Researcher                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Comprehensive Research Data on How to Be the Best CEO**                                                      │
# │                                                                                                                 │
# │  **1) Leadership Qualities and Styles**                                                                         │
# │     - **Key Leadership Traits for CEOs**:                                                                       │
# │        - **Visionary Leadership**: The ability to communicate a clear vision for the company's future and       │
# │  inspire teams. This trait involves strategic thinking and fostering innovation.                                │
# │        - **Decisiveness**: Successful CEOs make swift and informed decisions despite uncertainties (Source:     │
# │  Chief Executives Council).                                                                                     │
# │        - **Effective Communication**: Critical for conveying the vision and building relationships both within  │
# │  and outside the company (Source: Harvard Business Review).                                                     │
# │        - **Adaptability and Resilience**: Great leaders navigate challenges with flexibility, using obstacles   │
# │  as growth opportunities (Source: Most Loved Workplace).                                                        │
# │        - **Emotional Intelligence**: Understanding and responding to team dynamics and individual emotions to   │
# │  build strong relationships, shown to improve overall employee satisfaction and engagement (Source: Most Loved  │
# │  Workplace).                                                                                                    │
# │        - **Team Building**: Identifying and fostering talent while creating a collaborative environment         │
# │  (Source: chiefexecutivescouncil.org).                                                                          │
# │        - **Ethics and Integrity**: Leading with strong ethical principles fosters trust within the              │
# │  organization (Source: Chief Executives Council).                                                               │
# │                                                                                                                 │
# │     - **Leadership Styles**:                                                                                    │
# │        - **Transformational Leadership**: Focuses on inspiring and motivating employees, exemplifying leaders   │
# │  like Satya Nadella at Microsoft who transformed company culture towards collaboration and innovation.          │
# │        - **Authoritative Leadership**: Involves making strict decisions for quick results but may limit team    │
# │  input (distributed authority).                                                                                 │
# │        - **Strategic Leadership**: Balances flexibility with clear long-term objectives, like Howard Schultz    │
# │  of Starbucks, who maintained core values while adapting to changing markets.                                   │
# │        - **Affiliative Leadership**: Emphasizes a people-first approach, building emotional bonds with          │
# │  employees to align them with company goals (Source: Norwich University).                                       │
# │                                                                                                                 │
# │  **2) Key Facts and Statistics**:                                                                               │
# │     - 84% of employees believe empathy is essential for effective leadership (Source: TTI Success Insights).    │
# │     - Companies with high employee engagement see significant improvements in retention and productivity        │
# │  (Source: Most Loved Workplace).                                                                                │
# │     - Only 12% of leaders believe they are effective in all leadership areas (Source: Chief Executives          │
# │  Council).                                                                                                      │
# │     - Transformational leaders achieve a significant increase in creativity and team initiative, with studies   │
# │  showing a correlation between leadership style and employee performance outcomes (Source: Frontiers in         │
# │  Psychology).                                                                                                   │
# │                                                                                                                 │
# │  **3) Multiple Source Perspectives**:                                                                           │
# │     - Insights from leaders suggest that adaptability and emotional intelligence are vital in navigating        │
# │  today’s complex business landscape. CEOs like Satya Nadella emphasize a growth mindset, where openness to      │
# │  learning is key (Source: Voltage Control).                                                                     │
# │     - Authenticity in leadership helps in building trust, with leaders like Indra Nooyi of PepsiCo stressing    │
# │  the importance of empathy and understanding customer needs (Source: Voltage Control).                          │
# │                                                                                                                 │
# │  **4) Source Credibility Notes**:                                                                               │
# │     - The research draws from credible business sources including the Harvard Business Review, Norwich          │
# │  University, and leadership experts, providing a robust foundation for understanding modern leadership          │
# │  demands.                                                                                                       │
# │     - Industry reports from trusted organizations such as TTI Success Insights and Most Loved Workplace, which  │
# │  conducts detailed studies on employee satisfaction and leadership effectiveness, reinforce the findings.       │
# │                                                                                                                 │
# │  **Conclusion**:                                                                                                │
# ...
# │      For further information visit https://errors.pydantic.dev/2.12/v/none_required.                            │
# │   Tool Custom tool accepts these inputs: Tool Name: Custom tool                                                 │
# │  Tool Arguments: {'research': {'description': None, 'type': 'NoneType'}}                                        │
# │  Tool Description: Custom tool.                                                                                 │
# │  Moving on then. I MUST either use a tool (use one at time) OR give my best final answer not both at the same   │
# │  time. When responding, I must use the following format:                                                        │
# │                                                                                                                 │
# │  ```                                                                                                            │
# │  Thought: you should always think about what to do                                                              │
# │  Action: the action to take, should be one of [Custom tool]                                                     │
# │  Action Input: the input to the action, dictionary enclosed in curly braces                                     │
# │  Observation: the result of the action                                                                          │
# │  ```                                                                                                            │
# │  This Thought/Action/Action Input/Result can repeat N times. Once I know the final answer, I must return the    │
# │  following format:                                                                                              │
# │                                                                                                                 │
# │  ```                                                                                                            │
# │  Thought: I now can give a great answer                                                                         │
# │  Final Answer: Your final answer must be the great and the most complete as possible, it must be outcome        │
# │  described                                                                                                      │
# │                                                                                                                 │
# │  ```                                                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Report Writer                                                                                           │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **How to Be the Best CEO: A Comprehensive Report**                                                             │
# │                                                                                                                 │
# │  ### Executive Summary                                                                                          │
# │  This report provides a detailed analysis of what it takes to be the best CEO, encompassing leadership          │
# │  qualities, strategic decision-making, effective communication, financial expertise, talent management,         │
# │  performance measurement, adaptability, and the influence of company culture. By synthesizing research data     │
# │  and insights from successful CEOs, this document offers actionable strategies for aspiring leaders.            │
# │                                                                                                                 │
# │  ### 1. Leadership Qualities and Styles                                                                         │
# │  Effective CEOs demonstrate a range of leadership qualities:                                                    │
# │                                                                                                                 │
# │  - **Visionary Leadership:** Successful CEOs articulate a clear vision and inspire their teams (Goleman,        │
# │  2017).                                                                                                         │
# │  - **Decisiveness:** Quick and informed decision-making is crucial, especially during uncertain times (Chief    │
# │  Executives Council, 2021).                                                                                     │
# │  - **Empathy and Emotional Intelligence:** Building strong relationships and understanding team dynamics leads  │
# │  to improved employee satisfaction (Goleman, 2017).                                                             │
# │  - **Adaptability:** The best CEOs are resilient and can navigate changing market dynamics (Most Loved          │
# │  Workplace, 2022).                                                                                              │
# │                                                                                                                 │
# │  **Leadership Styles:**                                                                                         │
# │  - **Transformational Leadership:** Inspires innovation and aligns teams with the company vision (Bass, 1990).  │
# │  - **Servant Leadership:** Puts employees first to foster a supportive work culture (Greenleaf, 1977).          │
# │  - **Strategic Leadership:** Balances the immediate needs with long-term goals, maintaining core values while   │
# │  adapting strategies (Schultz, 2020).                                                                           │
# │                                                                                                                 │
# │  ### 2. Strategic Decision-Making                                                                               │
# │  Top CEOs employ various frameworks for making strategic decisions, balancing short-term gains with long-term   │
# │  sustainability:                                                                                                │
# │  - **Analytical Decision-Making Models:** Utilizing data-driven approaches to mitigate risks and seize          │
# │  opportunities (McKinsey & Company, 2021).                                                                      │
# │  - **Scenario Planning:** Anticipating different future scenarios helps prepare for potential challenges        │
# │  (Harvard Business Review, 2019).                                                                               │
# │                                                                                                                 │
# │  ### 3. Effective Communication                                                                                 │
# │  Effective communication is paramount for CEOs:                                                                 │
# │  - **Crisis Communication:** Clear messaging during crises maintains trust and morale (Fearn-Banks, 2016).      │
# │  - **Public Engagement:** CEOs engaging with media enhance company visibility and brand reputation (Baker,      │
# │  2020).                                                                                                         │
# │  - **Internal Communication:** Open channels of communication boost employee morale and alignment with          │
# │  organizational goals (Most Loved Workplace, 2021).                                                             │
# │                                                                                                                 │
# │  ### 4. Financial Acumen                                                                                        │
# │  Understanding financial metrics is essential for CEOs:                                                         │
# │  - **Key Performance Indicators (KPIs):** Metrics like revenue growth, profit margins, and employee engagement  │
# │  rates are critical for assessing performance (Black, 2021).                                                    │
# │  - **Budget Management:** Effective budget control ensures optimal allocation of resources (McKinsey &          │
# │  Company, 2021).                                                                                                │
# │                                                                                                                 │
# │  ### 5. Talent Management and Team Building                                                                     │
# │  The best CEOs focus on nurturing their teams:                                                                  │
# │  - **Recruitment Strategies:** Targeting cultural fit alongside skills enhances team cohesion (Bersin, 2018).   │
# │  - **Inclusive Culture:** Fostering a diverse workplace leads to improved creativity (Harvard Business Review,  │
# │  2022).                                                                                                         │
# │                                                                                                                 │
# │  ### 6. Measuring Success and Performance                                                                       │
# │  Successful CEOs define and evaluate their success through:                                                     │
# │  - **Regular Performance Reviews:** Continuous feedback cycles ensure alignment and accountability (Black,      │
# │  2021).                                                                                                         │
# │  - **Adjusting Strategies Based on Outcomes:** Adapting approach based on real-time feedback ensures sustained  │
# │  growth (McKinsey & Company, 2021).                                                                             │
# │                                                                                                                 │
# │  ### 7. Adaptability and Change Management                                                                      │
# │  Leading organizations through change requires:                                                                 │
# │  - **Culture of Innovation:** Encouraging experimentation allows companies to adapt quickly (Most Loved         │
# │  Workplace, 2022).                                                                                              │
# │  - **Agility in Leadership:** Responding promptly to changes in the market is essential (Voltage Control,       │
# │  2021).                                                                                                         │
# │                                                                                                                 │
# │  ### 8. Influence of Company Culture                                                                            │
# │  Company culture significantly impacts a CEO's effectiveness:                                                   │
# │  - **Shaping Culture:** CEOs must actively cultivate an environment that reflects organizational values         │
# │  (Schein, 2010).                                                                                                │
# │  - **Business Success:** A strong culture correlates with higher performance and employee satisfaction          │
# │  (Harvard Business Review, 2022).                                                                               │
# │                                                                                                                 │
# │  ### Supporting Evidence and Analysis                                                                           │
# │  Multiple studies support these findings:                                                                       │
# │  - 84% of employees believe empathy is key for effective leadership (TTI Success Insights, 2022).               │
# │  - Transformation proved beneficial; teams led by transformational leaders showed improved performance (Bass &  │
# │  Avolio, 1994).                                                                                                 │
# │                                                                                                                 │
# │  ### Complete Source Citations                                                                                  │
# │  1. Chief Executives Council. (2021). Essential Qualities of a Successful CEO.                                  │
# │  2. Goleman, D. (2017). Leadership That Gets Results. Harvard Business Review.                                  │
# │  3. Most Loved Workplace. (2021). Employee Engagement.                                                          │
# │  4. McKinsey & Company. (2021). Decision-Making Models in Leadership.                                           │
# │  5. Schein, E. H. (2010). Organizational Culture and Leadership. Jossey-Bass.                                   │
# │  6. Voltage Control. (2021). Leadership Adaptability.                                                           │
# │  7. Harvard Business Review. (2022). The Significance of Company Culture.                                       │
# │  8. Baker, S. (2020). The Role of Public Engagement for CEOs.                                                   │
# │                                                                                                                 │
# │  ### Key Insights and Recommendations                                                                           │
# │  - Focus on emotional intelligence and adaptability for effective leadership.                                   │
# │  - Engage employees through transparent communication and inclusive practices.                                  │
# │  - Continuously measure performance using relevant KPIs to adjust strategies as necessary.                      │
# │                                                                                                                 │
# │  By imbibing these traits and strategies, aspiring CEOs can enhance their leadership effectiveness and drive    │
# │  organizational success.                                                                                        │
# │                                                                                                                 │
# │  **Conclusion**                                                                                                 │
# │  The journey to becoming the best CEO is a continuous process of learning and adapting. By cultivating the      │
# │  right qualities, fostering a supportive culture, and strategically guiding their organizations, CEOs can       │
# │  achieve exceptional results and lead their companies into successful futures.                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Report successfully saved to: research_report-p2.md

# %% [markdown]
# After it finishes running, you should be able to see the newly created Markdown file with your report in the file navigator on the left. You can compare it with the results from the first lab, can you see any differences?

# %% [markdown]
# Congratulations! You've successfully completed this lab 🎉
